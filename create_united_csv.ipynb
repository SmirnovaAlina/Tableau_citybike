# %%
import pandas as pd

# %%
csv_2017_01 = "citybike_files/JC-201701-citibike-tripdata.csv"
csv_2017_01_df = pd.read_csv(csv_2017_01)
print(csv_2017_01_df.shape)
print(csv_2017_01_df.columns)
# Out:
# (12926, 15)
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')

# %%
csv_2017_01_df = csv_2017_01_df.rename(str.lower, axis='columns')
print(csv_2017_01_df.columns)
# Out:
# Index(['trip duration', 'start time', 'stop time', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bike id', 'user type',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2017_01_df = csv_2017_01_df.rename(index=str, columns={"trip duration": "tripduration", "start time": "starttime", "stop time": "stoptime",
                                         "bike id": "bikeid", "user type": "usertype"})
print(csv_2017_01_df.columns)
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2017_02 = "citybike_files/JC-201702-citibike-tripdata.csv"
csv_2017_02_df = pd.read_csv(csv_2017_02)
print(csv_2017_02_df.shape)
print(csv_2017_02_df.columns)
# Out:
# (14026, 15)
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')

# %%
csv_2017_02_df = csv_2017_02_df.rename(str.lower, axis='columns')
print(csv_2017_02_df.columns)
# Out:
# Index(['trip duration', 'start time', 'stop time', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bike id', 'user type',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2017_03 = "citybike_files/JC-201703-citibike-tripdata.csv"
csv_2017_03_df = pd.read_csv(csv_2017_03)
print(csv_2017_03_df.shape)
print(csv_2017_03_df.columns)
# Out:
# (12201, 15)
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')

# %%
csv_2017_02_df = csv_2017_02_df.rename(index=str, columns={"trip duration": "tripduration", "start time": "starttime", "stop time": "stoptime",
                                         "bike id": "bikeid", "user type": "usertype"})
print(csv_2017_02_df.columns)
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2017_03_df = csv_2017_03_df.rename(str.lower, axis='columns')
print(csv_2017_03_df.columns)
# Out:
# Index(['trip duration', 'start time', 'stop time', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bike id', 'user type',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2017_03_df = csv_2017_03_df.rename(index=str, columns={"trip duration": "tripduration", "start time": "starttime", "stop time": "stoptime",
                                         "bike id": "bikeid", "user type": "usertype"})
print(csv_2017_03_df.columns)
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2017_04 = "citybike_files/JC-201704-citibike-tripdata.csv"
csv_2017_04_df = pd.read_csv(csv_2017_04)
print(csv_2017_04_df.shape)
print(csv_2017_04_df.columns)
# Out:
# (21186, 15)
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2017_05 = "citybike_files/JC-201705-citibike-tripdata.csv"
csv_2017_05_df = pd.read_csv(csv_2017_05)
print(csv_2017_05_df.shape)
print(csv_2017_05_df.columns)
# Out:
# (25966, 15)
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2017_06 = "citybike_files/JC-201706-citibike-tripdata.csv"
csv_2017_06_df = pd.read_csv(csv_2017_06)
print(csv_2017_06_df.shape)
print(csv_2017_06_df.columns)
# Out:
# (32060, 15)
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2017_07 = "citybike_files/JC-201707-citibike-tripdata.csv"
csv_2017_07_df = pd.read_csv(csv_2017_07)
print(csv_2017_07_df.shape)
print(csv_2017_07_df.columns)
# Out:
# (33573, 15)
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2017_08 = "citybike_files/JC-201708 citibike-tripdata.csv"
csv_2017_08_df = pd.read_csv(csv_2017_08)
print(csv_2017_08_df.shape)
print(csv_2017_08_df.columns)
# Out:
# (35472, 15)
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2017_09 = "citybike_files/JC-201709-citibike-tripdata.csv"
csv_2017_09_df = pd.read_csv(csv_2017_09)
print(csv_2017_09_df.shape)
print(csv_2017_09_df.columns)
# Out:
# (33119, 15)
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2017_10 = "citybike_files/JC-201710-citibike-tripdata.csv"
csv_2017_10_df = pd.read_csv(csv_2017_10)
print(csv_2017_10_df.shape)
print(csv_2017_10_df.columns)
# Out:
# (34919, 15)
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2017_11 = "citybike_files/JC-201711-citibike-tripdata.csv"
csv_2017_11_df = pd.read_csv(csv_2017_11)
print(csv_2017_11_df.shape)
print(csv_2017_11_df.columns)
# Out:
# (23582, 15)
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2017_12 = "citybike_files/JC-201712-citibike-tripdata.csv"
csv_2017_12_df = pd.read_csv(csv_2017_12)
print(csv_2017_12_df.shape)
print(csv_2017_12_df.columns)
# Out:
# (15898, 15)
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
df_union_all_2017= pd.concat([csv_2017_01_df, csv_2017_02_df, csv_2017_03_df, csv_2017_04_df, csv_2017_05_df, csv_2017_06_df,
                              csv_2017_07_df, csv_2017_08_df, csv_2017_09_df, csv_2017_10_df, csv_2017_01_df, csv_2017_11_df, csv_2017_12_df])
df_union_all_2017.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           148  2017-01-01 00:21:32  2017-01-01 00:24:01              3276
# 1          1283  2017-01-01 00:24:35  2017-01-01 00:45:58              3183
# 2           372  2017-01-01 00:38:19  2017-01-01 00:44:31              3183
# 3          1513  2017-01-01 00:38:37  2017-01-01 01:03:50              3194
# 4           639  2017-01-01 01:47:52  2017-01-01 01:58:31              3183
#
#   start station name  start station latitude  start station longitude  \
# 0   Marin Light Rail               40.714584               -74.042817
# 1     Exchange Place               40.716247               -74.033459
# 2     Exchange Place               40.716247               -74.033459
# 3    McGinley Square               40.725340               -74.067622
# 4     Exchange Place               40.716247               -74.033459
#
#    end station id     end station name  end station latitude  \
# ...

# %%
df_union_all_2017.to_csv("union_all_2017.csv", index=False, header=True)

# %%
csv_2018_01 = "citybike_files/JC-201801-citibike-tripdata.csv"
csv_2018_01_df = pd.read_csv(csv_2018_01)
print(csv_2018_01_df.shape)
print(csv_2018_01_df.columns)
# Out:
# (12677, 15)
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2018_02 = "citybike_files/JC-201802-citibike-tripdata.csv"
csv_2018_02_df = pd.read_csv(csv_2018_02)
print(csv_2018_02_df.shape)
print(csv_2018_02_df.columns)
# Out:
# (15104, 15)
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2018_03 = "citybike_files/JC-201803-citibike-tripdata.csv"
csv_2018_03_df = pd.read_csv(csv_2018_03)
print(csv_2018_03_df.shape)
print(csv_2018_03_df.columns)
# Out:
# (17109, 15)
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2018_04 = "citybike_files/JC-201804-citibike-tripdata.csv"
csv_2018_04_df = pd.read_csv(csv_2018_04)
print(csv_2018_04_df.shape)
print(csv_2018_04_df.columns)
# Out:
# (23634, 15)
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2018_05 = "citybike_files/JC-201805-citibike-tripdata.csv"
csv_2018_05_df = pd.read_csv(csv_2018_05)
print(csv_2018_05_df.shape)
print(csv_2018_05_df.columns)
# Out:
# (34456, 15)
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2018_06 = "citybike_files/JC-201806-citibike-tripdata.csv"
csv_2018_06_df = pd.read_csv(csv_2018_06)
print(csv_2018_06_df.shape)
print(csv_2018_06_df.columns)
# Out:
# (40937, 15)
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2018_07 = "citybike_files/JC-201807-citibike-tripdata.csv"
csv_2018_07_df = pd.read_csv(csv_2018_07)
print(csv_2018_07_df.shape)
print(csv_2018_07_df.columns)
# Out:
# (42268, 15)
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2018_08 = "citybike_files/JC-201808-citibike-tripdata.csv"
csv_2018_08_df = pd.read_csv(csv_2018_08)
print(csv_2018_08_df.shape)
print(csv_2018_08_df.columns)
# Out:
# (44432, 15)
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2018_09 = "citybike_files/JC-201809-citibike-tripdata.csv"
csv_2018_09_df = pd.read_csv(csv_2018_09)
print(csv_2018_09_df.shape)
print(csv_2018_09_df.columns)
# Out:
# (39022, 15)
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2018_10 = "citybike_files/JC-201810-citibike-tripdata.csv"
csv_2018_10_df = pd.read_csv(csv_2018_10)
print(csv_2018_10_df.shape)
print(csv_2018_10_df.columns)
# Out:
# (39138, 15)
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2018_11 = "citybike_files/JC-201811-citibike-tripdata.csv"
csv_2018_11_df = pd.read_csv(csv_2018_11)
print(csv_2018_11_df.shape)
print(csv_2018_11_df.columns)
# Out:
# (24910, 15)
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2018_12 = "citybike_files/JC-201812-citibike-tripdata.csv"
csv_2018_12_df = pd.read_csv(csv_2018_12)
print(csv_2018_12_df.shape)
print(csv_2018_12_df.columns)
# Out:
# (20205, 15)
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
df_union_all_2018= pd.concat([csv_2018_01_df, csv_2018_02_df, csv_2018_03_df, csv_2018_04_df, csv_2018_05_df, csv_2018_06_df,
                              csv_2018_07_df, csv_2018_08_df, csv_2018_09_df, csv_2018_10_df, csv_2018_01_df, csv_2018_11_df, csv_2018_12_df])
df_union_all_2018.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1           550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2           510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3           354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4           250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3199     Newport Pkwy
# ...

# %%
df_union_all_2018.to_csv("union_all_2018.csv", index=False, header=True)

# %%
csv_2019_01 = "citybike_files/JC-201901-citibike-tripdata.csv"
csv_2019_01_df = pd.read_csv(csv_2019_01)
print(csv_2019_01_df.shape)
print(csv_2019_01_df.columns)
# Out:
# (19676, 15)
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2019_02 = "citybike_files/JC-201902-citibike-tripdata.csv"
csv_2019_02_df = pd.read_csv(csv_2019_02)
print(csv_2019_02_df.shape)
print(csv_2019_02_df.columns)
# Out:
# (18565, 15)
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2019_03 = "citybike_files/JC-201903-citibike-tripdata.csv"
csv_2019_03_df = pd.read_csv(csv_2019_03)
print(csv_2019_03_df.shape)
print(csv_2019_03_df.columns)
# Out:
# (23606, 15)
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
csv_2019_04 = "citybike_files/JC-201901-citibike-tripdata.csv"
csv_2019_04_df = pd.read_csv(csv_2019_04)
print(csv_2019_04_df.shape)
print(csv_2019_04_df.columns)
# Out:
# (19676, 15)
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
df_union_all_2019= pd.concat([csv_2019_01_df, csv_2019_02_df, csv_2019_03_df, csv_2019_04_df])
df_union_all_2019.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1           505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2           756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3          1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4          1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
df_union_all_2019.to_csv("union_all_2019.csv", index=False, header=True)

# %%
csv_2016_01 = "citybike_files/JC-201601-citibike-tripdata.csv"
csv_2016_01_df = pd.read_csv(csv_2016_01)
print(csv_2016_01_df.shape)
print(csv_2016_01_df.columns)
# Out:
# (7479, 15)
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')

# %%
csv_2016_02 = "citybike_files/JC-201602-citibike-tripdata.csv"
csv_2016_02_df = pd.read_csv(csv_2016_02)
print(csv_2016_02_df.shape)
print(csv_2016_02_df.columns)
# Out:
# (8250, 15)
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')

# %%
csv_2016_03 = "citybike_files/JC-201603-citibike-tripdata.csv"
csv_2016_03_df = pd.read_csv(csv_2016_03)
print(csv_2016_03_df.shape)
print(csv_2016_03_df.columns)
# Out:
# (13511, 15)
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')

# %%
csv_2016_04 = "citybike_files/JC-201601-citibike-tripdata.csv"
csv_2016_04_df = pd.read_csv(csv_2016_04)
print(csv_2016_04_df.shape)
print(csv_2016_04_df.columns)
# Out:
# (7479, 15)
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')

# %%
csv_2016_05 = "citybike_files/JC-201605-citibike-tripdata.csv"
csv_2016_05_df = pd.read_csv(csv_2016_05)
print(csv_2016_05_df.shape)
print(csv_2016_05_df.columns)
# Out:
# (19488, 15)
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')

# %%
csv_2016_06 = "citybike_files/JC-201606-citibike-tripdata.csv"
csv_2016_06_df = pd.read_csv(csv_2016_06)
print(csv_2016_06_df.shape)
print(csv_2016_06_df.columns)
# Out:
# (23947, 15)
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')

# %%
csv_2016_07 = "citybike_files/JC-201607-citibike-tripdata.csv"
csv_2016_07_df = pd.read_csv(csv_2016_07)
print(csv_2016_07_df.shape)
print(csv_2016_07_df.columns)
# Out:
# (24436, 15)
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')

# %%
csv_2016_08 = "citybike_files/JC-201608-citibike-tripdata.csv"
csv_2016_08_df = pd.read_csv(csv_2016_01)
print(csv_2016_08_df.shape)
print(csv_2016_08_df.columns)
# Out:
# (7479, 15)
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')

# %%
csv_2016_09 = "citybike_files/JC-201609-citibike-tripdata.csv"
csv_2016_09_df = pd.read_csv(csv_2016_09)
print(csv_2016_09_df.shape)
print(csv_2016_09_df.columns)
# Out:
# (33425, 15)
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')

# %%
csv_2016_10 = "citybike_files/JC-201610-citibike-tripdata.csv"
csv_2016_10_df = pd.read_csv(csv_2016_10)
print(csv_2016_10_df.shape)
print(csv_2016_10_df.columns)
# Out:
# (29611, 15)
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')

# %%
csv_2016_11 = "citybike_files/JC-201611-citibike-tripdata.csv"
csv_2016_11_df = pd.read_csv(csv_2016_11)
print(csv_2016_11_df.shape)
print(csv_2016_11_df.columns)
# Out:
# (21832, 15)
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')

# %%
csv_2016_12 = "citybike_files/JC-201612-citibike-tripdata.csv"
csv_2016_12_df = pd.read_csv(csv_2016_12)
print(csv_2016_12_df.shape)
print(csv_2016_12_df.columns)
# Out:
# (15114, 15)
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')

# %%
df_union_all_2016= pd.concat([csv_2016_01_df, csv_2016_02_df, csv_2016_03_df, csv_2016_04_df, csv_2016_05_df, csv_2016_06_df,
                              csv_2016_07_df, csv_2016_08_df, csv_2016_09_df, csv_2016_10_df, csv_2016_01_df, csv_2016_11_df, csv_2016_12_df])
df_union_all_2016.head()
# Out:
#        Trip Duration           Start Time            Stop Time  \
# 0                362  2016-01-01 00:02:52  2016-01-01 00:08:54
# 1                200  2016-01-01 00:18:22  2016-01-01 00:21:42
# 2                202  2016-01-01 00:18:25  2016-01-01 00:21:47
# 3                248  2016-01-01 00:23:13  2016-01-01 00:27:21
# 4                903  2016-01-01 01:03:20  2016-01-01 01:18:24
# 5                883  2016-01-01 01:03:28  2016-01-01 01:18:11
# 6                445  2016-01-01 01:07:45  2016-01-01 01:15:11
# 7                192  2016-01-01 01:18:51  2016-01-01 01:22:03
# 8                409  2016-01-01 01:23:44  2016-01-01 01:30:34
# 9                285  2016-01-01 01:25:12  2016-01-01 01:29:57
# 10               206  2016-01-01 01:45:34  2016-01-01 01:49:00
# 11               251  2016-01-01 02:02:55  2016-01-01 02:07:06
# 12               292  2016-01-01 02:20:38  2016-01-01 02:25:30
# 13               175  2016-01-01 02:23:37  2016-01-01 02:26:32
# ...

# %%
df_union_all_2016.to_csv()
